# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# a. Importing the libraries

# %%
import pandas as pd

# %% [markdown]
# # Measure of Central Tendency

# %% [markdown]
# b. Import the dataset and create a random sample of size = 20

# %%
a = 15
b = 10

x = a+ b

x
# Out:
# 25

# %% [markdown]
# c. Find the average of each column

# %% [markdown]
# d. Find the average of Final marks

# %% [markdown]
# e. Find the average marks obtained by each student – row wise mean

# %% [markdown]
# f. Find the middle mark of the all exams

# %% [markdown]
# g. Find the middle mark of the Final marks

# %% [markdown]
# h. Which department have more entries

# %% [markdown]
# # Measure of Dispersion

# %% [markdown]
# i. Find the minimum marks scored in the final

# %% [markdown]
# j. Find the maximum marks scored in the final

# %% [markdown]
# k. Find the range of marks scored in the final

# %% [markdown]
# l. Find how finals marks are deviated from the average

# %% [markdown]
# m. Find the variance of the final marks - square of std dev

# %% [markdown]
# # Measure of Position

# %% [markdown]
# n. Find the variance of the final marks - square of std dev

# %% [markdown]
# o. Check the kurtosis of final marks

# %% [markdown]
# p. Find the different quantiles for the final marks

# %% [markdown]
# q. Find the different quantiles for the final marks

# %% [markdown]
# r. Draw the box plot for quartiles of final marks using mat plot library

# %% [markdown]
# s. Draw the box plot for quartiles of final marks department wise using sea born library

# %% [markdown]
# # Measure of Frequency

# %% [markdown]
# t. Find the number of students

# %% [markdown]
# u. Find the number of students division wise - absolute frequency

# %% [markdown]
# v. Find the number of students division wise with respect to total students - relative frequency

# %% [markdown]
# # Function to find the Descriptive Statistics

# %% [markdown]
# w. Find the descriptive Statistics for all columns

# %% [markdown]
# x. Create a function to display descriptive stat for the given dataset and field

# %% [markdown]
# # Apply Descriptive Statistics for Random Sampling

# %% [markdown]
# y. Find the descriptive statistics for the Final column
